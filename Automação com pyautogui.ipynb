# %% [markdown]
# VAMOS USAR A BIBLIOTECA PYAUTOGUI
#
# PASSO A PASSO:
#
# PASSO 1 - ENTRAR NO SISTEMA DA EMPRESA, LINK: https://drive.google.com/drive/folders/149xknr9JvrlEnhNWO49zPcw0PW5icxga?usp=sharing
# PASSO 2 - NAVEGAR ATÉ O LOCAL ONDE ESTÁ A NOSSA BASE DE DADOS (ENTRAR NA PASTA "EXPORTAR")
# PASSO 3 - BAIXAR PLANILHA DE VENDAS
#
# PASSO 4 - CALCULAR O FATURAMENTE E QUANTIDADE DE PRODUTOS VENDIDOS DA BASE
#
# PASSO 5Relatório de vendas
# Prezados,
#
# Segue o relatorio de vendas
# O faturamento de ontem foi: R$2,917,311.00
# E a quantidade de vendas foi: 15,227
#
# Abs
# Jack Automation
# - ENVIAR EMAIL PAR A DIRETORIA COM A QUANTIDADE E O FATURAMENTO QUE CALCULAMOS

# %%
import pyautogui
import time # faz o computaodr ficar parado durante o tempo determiando em segundos
import pyperclip # usado para copiar e colar neste código

pyautogui.PAUSE = 1

#passo 1
#Abrindo nova aba no navegador

pyautogui.hotkey('ctrl', 't')
link = "https://drive.google.com/drive/folders/149xknr9JvrlEnhNWO49zPcw0PW5icxga?usp=sharing"
pyperclip.copy(link)
pyautogui.hotkey('ctrl','v')
pyautogui.press("enter")

#Passo 2:
time.sleep(5)
pyautogui.click(2479,1009, clicks=2)

#Passo 3:
#clicar no arquivo:
time.sleep(4)
pyautogui.click(2522,1152)
#clicar nos 3 pontinhos:
time.sleep(4)
pyautogui.click(3543,817)
#clicando em download:
pyautogui.click(3201,1381)
time.sleep(5)
pyautogui.hotkey('ctrl','w')


#passo 4:
import pandas as pd

tabela = pd.read_excel(r"D:\Usuário\Downloads\Vendas - Dez.xlsx")
#pode ser usado o display ao invés de print, para uma melhor vizualização.
faturamento = tabela["Valor Final"].sum() # soma da coluna valor final
quantidade = tabela["Quantidade"].sum()# soma da coluna quantidade
display(tabela)
#Passo 5:
#Abrindo nova aba
pyautogui.hotkey('ctrl', 't')
#entrando no gmail
time.sleep(10)
linkGmail = "https://mail.google.com/"
pyperclip.copy(linkGmail)
pyautogui.hotkey('ctrl','v')
pyautogui.hotkey('enter')
#Clicando em escrever no gmail
pyautogui.click(1920,859)
pyautogui.write("jsilvacco+aulapython@.com")
pyautogui.press("tab")
time.sleep(4)
pyautogui.press("tab")
assunto = "Relatório de vendas"
pyperclip.copy(assunto)
pyautogui.hotkey('ctrl','v')
pyautogui.press("tab")
time.sleep(4)
texto_email = f'''
Prezados,

Segue o relatorio de vendas
O faturamento de ontem foi: R${faturamento:,.2f}
E a quantidade de vendas foi: {quantidade:,}

Abs
Jack Automation
'''
pyautogui.write(texto_email)
time.sleep(4)
#clicar em enviar email
pyautogui.hotkey('ctrl','enter')
# Out:
#       Código Venda       Data                     ID Loja           Produto  \
# 0            65014 2019-12-01            Shopping Morumbi    Sunga Listrado
# 1            65014 2019-12-01            Shopping Morumbi   Casaco Listrado
# 2            65016 2019-12-01           Iguatemi Campinas   Sapato Listrado
# 3            65016 2019-12-01           Iguatemi Campinas            Casaco
# 4            65017 2019-12-01          Shopping SP Market        Gorro Liso
# ...            ...        ...                         ...               ...
# 7084         69996 2019-12-26  Center Shopping Uberlândia    Short Listrado
# 7085         69996 2019-12-26  Center Shopping Uberlândia           Mochila
# 7086         69996 2019-12-26  Center Shopping Uberlândia  Pulseira Estampa
# 7087         69997 2019-12-26           Ribeirão Shopping   Camisa Listrado
# 7088         69997 2019-12-26           Ribeirão Shopping       Short Linho
#
#       Quantidade  Valor Unitário  Valor Final
# ...

# %%
time.sleep(5)
pyautogui.position()
# Out:
# Point(x=2912, y=1934)

# %%
# Out:
#       Código Venda       Data                     ID Loja           Produto  \
# 0            65014 2019-12-01            Shopping Morumbi    Sunga Listrado
# 1            65014 2019-12-01            Shopping Morumbi   Casaco Listrado
# 2            65016 2019-12-01           Iguatemi Campinas   Sapato Listrado
# 3            65016 2019-12-01           Iguatemi Campinas            Casaco
# 4            65017 2019-12-01          Shopping SP Market        Gorro Liso
# ...            ...        ...                         ...               ...
# 7084         69996 2019-12-26  Center Shopping Uberlândia    Short Listrado
# 7085         69996 2019-12-26  Center Shopping Uberlândia           Mochila
# 7086         69996 2019-12-26  Center Shopping Uberlândia  Pulseira Estampa
# 7087         69997 2019-12-26           Ribeirão Shopping   Camisa Listrado
# 7088         69997 2019-12-26           Ribeirão Shopping       Short Linho
#
#       Quantidade  Valor Unitário  Valor Final
# ...
